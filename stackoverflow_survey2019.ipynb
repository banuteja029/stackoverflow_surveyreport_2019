# %%
import os
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
os.chdir(r'D:\developer_survey_2019')

# %%
dataset=pd.read_csv('survey_results_public.csv')

# %%
dataset.head(10)  #return 0 to n-1 data
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
dataset.tail()   #tail returns bottom of the dataset
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
dataset.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
dataset.size
# Out:
# 7555055

# %%
dataset.memory_usage(index=True,deep=True)  #returns memory usage of each column in bytes
# Out:
# Index               128
# Respondent       711064
# MainBranch      8169470
# Hobbyist        5315354
# OpenSourcer     7117642
#                  ...
# Sexuality       6439138
# Ethnicity       6759938
# Dependents      5119181
# SurveyLength    6468692
# SurveyEase      5967052
# Length: 86, dtype: int64

# %%
dataset.shape  #shape return no of (rows,columns)
# Out:
# (88883, 85)

# %%
dataset.ndim  #no of dimensions(axes)
# Out:
# 2

# %%
dataset.at[5,'Country']   #to fetch particular record from the dataset syntax: datasetname.at[rowno,columnname]
# Out:
# 'Canada'

# %%
dataset.iat[10,18]
# Out:
# nan

# %%
dataset.iat[8,6]  #iat is used to when we knew the index of both rows and columns syntax: dataset.iat[rowindex,columnindex]
# Out:
# 'New Zealand'

# %%
loc() is used to return the data of particular columns of every row

# %%
dataset.loc[1,'JobSeek']  #1st row of column syntax:[rowindex,columnname]
# Out:
# 'I am actively looking for a job'

# %%
dataset.loc[:,'JobSeek']
# Out:
# 0                                                      NaN
# 1                          I am actively looking for a job
# 2        I’m not actively looking, but I am open to new...
# 3             I am not interested in new job opportunities
# 4             I am not interested in new job opportunities
#                                ...
# 88878                                                  NaN
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882                                                  NaN
# Name: JobSeek, Length: 88883, dtype: object
